# %% [markdown]
# <a href="https://colab.research.google.com/github/mouha07/abdou-ahad/blob/main/PROJET_WEB_SEMANTIQUE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Projet Web Sémantique

# %% [markdown]
# Présentation des membres du groupe:
#
#
#
# *   Mamadou Yaya MANE                       P32 3752
# *   Mouhamadou DIALLO                       P32 3743
# *   Cheikh Abdoul Ahad Mbacké DIOP          P32 3752

# %% [markdown]
# # Data Collection

# %%
# !pip install sparqlwrapper
# Out:
# Requirement already satisfied: sparqlwrapper in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.10/dist-packages (from sparqlwrapper) (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=6.1.1->sparqlwrapper) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=6.1.1->sparqlwrapper) (3.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->sparqlwrapper) (1.16.0)

# %% [markdown]
# Importation

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import csv
import pandas as pd
from datetime import datetime

# %%
def execute_sparql_query(endpoint, query):
    # Fonction pour exécuter une requête SPARQL sur le point d'accès SPARQL spécifié
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results

# %%
def generate_transactional_file(results, output_file_path):
    # Écrire les résultats SPARQL dans un fichier CSV
    with open(output_file_path, mode='w', newline='', encoding='utf-8') as csv_file:
        fieldnames = ["entity", "itemset"]
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

        # Écrire l'en-tête du fichier CSV
        writer.writeheader()

        # Écrire chaque ligne de résultats dans le fichier CSV
        for result in results:
            # Assurez-vous que les données sont encodées en utf-8 avant l'écriture
            encoded_result = {key: value.encode('utf-8').decode('utf-8') if isinstance(value, str) else value for key, value in result.items()}
            writer.writerow(encoded_result)

# %%
# Obtenir la date et l'heure actuelles
maintenant = datetime.now()

# Formater la date selon le format spécifié (dd-mm-yyyy H:m:s)
date_formattee = maintenant.strftime("%d-%m-%Y %H:%M:%S")


def collect_artist_data():
    endpoint = "http://dbpedia.org/sparql"
    query = """
    PREFIX dbo: <http://dbpedia.org/ontology/>
    SELECT ?entity (GROUP_CONCAT(DISTINCT ?predicate; separator=",") AS ?itemset)
    WHERE {
      # ?entity a dbo:Artist .
      # ?entity ?predicate ?object .
      FILTER(isURI(?object) || isLiteral(?object))
      FILTER(contains(str(?predicate), str(dbo:)))
      FILTER(!contains(str(?predicate), "wikiPage"))
      FILTER(!contains(str(?predicate), "abstract"))
      FILTER(!contains(str(?predicate), "thumbnail"))
      FILTER(!contains(str(?predicate), "birthDate"))
      FILTER(!contains(str(?predicate), "birthPlace"))
      FILTER(!contains(str(?predicate), "birthYear"))
    } GROUP BY ?entity
    """

    results = execute_sparql_query(endpoint, query)
    artist_data = []

    for result in results["results"]["bindings"]:
        entity = result["entity"]["value"]
        itemset = result["itemset"]["value"]
        artist_data.append({"entity": entity, "itemset": itemset})

    # Appel de la fonction pour générer le fichier transactionnel En spécifiant la date sur le nom du fichier
    generate_transactional_file(artist_data, f"TRANSACTION_{date_formattee}.csv")

    return artist_data

# %%
artist_data = collect_artist_data()

# Afficher les données des artistes
for data in artist_data:
    print(f"Entity: {data['entity']}, Itemset: {data['itemset']}")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Entity: http://dbpedia.org/resource/Ferron, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Filous, Itemset: http://dbpedia.org/ontology/activeYearsStartYear
# Entity: http://dbpedia.org/resource/Flood_(producer), Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Flora_Macdonald_Reid, Itemset: http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Florence_Pash, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/field
# Entity: http://dbpedia.org/resource/Folke_Sundquist, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/deathYear,http://dbpedia.org/ontology/nationality,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Foil_Arms_and_Hog, Itemset: http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Fran_Matera, Itemset: http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/
Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/occupation,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Kelly_Padrick, Itemset: http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Ken_Thomas_(record_producer), Itemset: http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/imdbId,http://dbpedia.org/ontology/occupation,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Kenneth_Platts, Itemset: http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Kenny_Sabir, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/KillBeatz, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Kinetics_(rapper), Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown
# Entity: http://dbpedia.org/resource/Konstantin_Dimopoulos, Itemset: http://dbpedia.org/ontology/birthName
# Entity: http://dbpedia.org/resource/Margret_Craver, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/field
# Entity: http://dbpedia.org/resource/Pascale_Criton, Itemset: http://dbpedia.org/ontology/background
# Entity: http://dbpedia.org/resource/Robert_Dowland, Itemset: http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Raffaellino_del_Garbo, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/nationality,http://dbpedia.org/ontology/training
# Entity: http://dbpedia.org/resource/Nelson_Gonçalves, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Roman_Glick, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Priestess_(rapper), Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/N._S._Ramachandran, Itemset: http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/RationaL_(rapper), Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown
# Entity: http://dbpedia.org/resource/Richard_Hudson_(sculptor), Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/field
# Entity: http://dbpedia.org/resource/Robert_O._Ragland, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/imdbId
# Entity: http://dbpedia.org/resource/Marie_Lorenz, Itemset: http://dbpedia.org/ontology/country
# Entity: http://dbpedia.org/resource/Green_Velvet, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Marin_Gradac, Itemset: http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/instrument
# Entity: http://dbpedia.org/resource/Gregorio_Vásquez_de_Arce_y_Ceballos, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/movement,http://dbpedia.org/ontology/nationality,http://dbpedia.org/ontology/notableWork
# Entity: http://dbpedia.org/resource/Gregory_S._Glasson, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/instrument
# Entity: http://dbpedia.org/resource/Gregory_Clark_(economist), Itemset: http://dbpedia.org/ontology/almaMater,http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/institution
# Entity: http://dbpedia.org/resource/Grey_Ghost_(musician), Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Grigory_Gurkin, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/movement,http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Gull_Natorp, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/deathYear,http://dbpedia.org/ontology/nationality,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Gulddreng, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Gunter_Christmann, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/field
# Entity: http://dbpedia.org/resource/Gunter_Gabriel, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace
# Entity: http://dbpedia.org/resource/Gustavo_Thorlichen, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/deathDate
# Entity: http://dbpedia.org/resource/Guy_Mitchell, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Guy_Hovis, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/hometown
# Entity: http://dbpedia.org/resource/Guy_de_Montlaur, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/movement,http://dbpedia.org/ontology/training
# Entity: http://dbpedia.org/resource/Guy_Sigsworth, Itemset: http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/hometown,http://dbpedia.org/ontology/instrument
# Entity: http://dbpedia.org/resource/Gyanu_Rana, Itemset: http://dbpedia.org/ontology/instrument
# Entity: http://dbpedia.org/resource/Habib_Samaei, Itemset: http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/hometown,http://dbpedia.org/ontology/instrument
# Entity: http://dbpedia.org/resource/Halina_Czerny-Stefańska, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/instrument,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Halina_Frąckowiak, Itemset: http://dbpedia.org/ontology/alias
# Entity: http://dbpedia.org/resource/Hammer_of_The_Last_Two, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Hanin_Elias, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Hannah_Maynard, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/spouse
# Entity: http://dbpedia.org/resource/Hans_Malmberg, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Hans_Makart, Itemset: http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/movement
# Entity: http://dbpedia.org/resource/Hanz_On, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown
# Entity: http://dbpedia.org/resource/Harald_Blüchel, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/occupation,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Harold_Weston, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/movement
# Entity: http://dbpedia.org/resource/Harry_Anderson_(artist), Itemset: http://dbpedia.org/ontology/award,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/training
# Entity: http://dbpedia.org/resource/Harry_Clarke, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/movement,http://dbpedia.org/ontology/restingPlace,http://dbpedia.org/ontology/spouse
# Entity: http://dbpedia.org/resource/Harry_James_Powell, Itemset: http://dbpedia.org/ontology/award,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/movement
# Entity: http://dbpedia.org/resource/Harv, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Harvey_Lloyd, Itemset: http://dbpedia.org/ontology/training
# Entity: http://dbpedia.org/resource/Hasan_&_Ibrahim, Itemset: http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Hasegawa_Tōhaku, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/movement,http://dbpedia.org/ontology/nationality,http://dbpedia.org/ontology/notableWork
# Entity: http://dbpedia.org/resource/Hasret_Gültekin, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace
# Entity: http://dbpedia.org/resource/Haval_(rapper), Itemset: http://dbpedia.org/ontology/activeYearsStartYear
# Entity: http://dbpedia.org/resource/Hawk_Wolinski, Itemset: http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/imdbId,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Haydn_Bendall, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Hazel_Dickens, Itemset: http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Heida_Mobeck, Itemset: http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/instrument,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Heiner_Thiel, Itemset: http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/movement
# Entity: http://dbpedia.org/resource/Heinz_Winckler, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/hometown
# Entity: http://dbpedia.org/resource/Helen_Desha_Beamer, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Helena_Markson, Itemset: http://dbpedia.org/ontology/country
# Entity: http://dbpedia.org/resource/Helene_Cramer, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/movement,http://dbpedia.org/ontology/training
# Entity: http://dbpedia.org/resource/Henriette_Valium, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/deathDate
# Entity: http://dbpedia.org/resource/Henriette_Wyeth, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/spouse
# Entity: http://dbpedia.org/resource/Henry_Katzman, Itemset: http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Henry_Santos, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Henry_Naylor, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/imdbId,http://dbpedia.org/ontology/spouse
# Entity: http://dbpedia.org/resource/Henry_Strzelecki, Itemset: http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/instrument
# Entity: http://dbpedia.org/resource/Henry_Small_(singer), Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Henryk_Wieniawski, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Hera_Hjartardóttir, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Herobust, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/instrument,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Hideji_Ōtaki, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/deathYear,http://dbpedia.org/ontology/imdbId,http://dbpedia.org/ontology/nationality,http://dbpedia.org/ontology/occupation,http://dbpedia.org/ontology
Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Jon_Ballantyne, Itemset: http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Jonathon_TeBeest, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background
# Entity: http://dbpedia.org/resource/Jonathan_Berger, Itemset: http://dbpedia.org/ontology/country
# Entity: http://dbpedia.org/resource/Jonathan_Hodge, Itemset: http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Jordan_Katembula, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background
# Entity: http://dbpedia.org/resource/Julian_Fauth, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown,http://dbpedia.org/ontology/occupation,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Julian_Colbeck, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist
# Entity: http://dbpedia.org/resource/Julia_Bracken_Wendt, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/spouse
# Entity: http://dbpedia.org/resource/Julie_Sheehan, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/training
# Entity: http://dbpedia.org/resource/Julius_Schmidt-Felling, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/movement
# Entity: http://dbpedia.org/resource/Julien-Honoré-Germain_d'Aubuisson, Itemset: http://dbpedia.org/ontology/country
# Entity: http://dbpedia.org/resource/Juri_Kimura, Itemset: http://dbpedia.org/ontology/Person/height,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/height,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Jussi_Lehtisalo, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown
# Entity: http://dbpedia.org/resource/Junya_Yamaguchi, Itemset: http://dbpedia.org/ontology/instrument
# Entity: http://dbpedia.org/resource/Jun_T._Lai, Itemset: http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Justin_Pickett, Itemset: http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/imdbId
# Entity: http://dbpedia.org/resource/Justin_Gignac, Itemset: http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/K._Silem_Mohammad, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/movement
# Entity: http://dbpedia.org/resource/K-Hito, Itemset: http://dbpedia.org/ontology/imdbId
# Entity: http://dbpedia.org/resource/Józef_Płoszko, Itemset: http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/nationality,http://dbpedia.org/ontology/notableWork,http://dbpedia.org/ontology/training
# Entity: http://dbpedia.org/resource/Karl_Hinds, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown,http://dbpedia.org/ontology/occupation,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Kase2, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/deathPlace,http://dbpedia.org/ontology/field
# Entity: http://dbpedia.org/resource/Kasia_Livingston, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Kasim_Keto, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown,http://dbpedia.org/ontology/instrument,http://dbpedia.org/ontology/occupation,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Kasiva_Mutua, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/hometown
# Entity: http://dbpedia.org/resource/Karol_Bennett, Itemset: http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Karolina_Micuła, Itemset: http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Kath_Bloom, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown
# Entity: http://dbpedia.org/resource/Katarina_Pejak, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Kate_Rogers, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Kate_McLennan, Itemset: http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/imdbId
# Entity: http://dbpedia.org/resource/Lana_Whiskeyjack, Itemset: http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Larry_Gales, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/instrument
# Entity: http://dbpedia.org/resource/Larry_Noble_(actor), Itemset: http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/imdbId
# Entity: http://dbpedia.org/resource/Lasmid, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Laufer_(musician), Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/imdbId,http://dbpedia.org/ontology/instrument
# Entity: http://dbpedia.org/resource/Lars_Stalfors, Itemset: http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/genre
# Entity: http://dbpedia.org/resource/Laura_Clayton, Itemset: http://dbpedia.org/ontology/country
# Entity: http://dbpedia.org/resource/Lasse_Petterson, Itemset: http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Lauren_Lucas, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/associatedBand,http://dbpedia.org/ontology/associatedMusicalArtist,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Lauren_McCrostie, Itemset: http://dbpedia.org/ontology/imdbId,http://dbpedia.org/ontology/notableWork
# Entity: http://dbpedia.org/resource/Laura_Marie_Greenwood, Itemset: http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/movement,http://dbpedia.org/ontology/training
# Entity: http://dbpedia.org/resource/Laurence_Stevens, Itemset: http://dbpedia.org/ontology/country,http://dbpedia.org/ontology/occupation
# Entity: http://dbpedia.org/resource/Lawrence_%22Teddy_Boy%22_Houle, Itemset: http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/instrument
# Entity: http://dbpedia.org/resource/Laurie_Trok, Itemset: http://dbpedia.org/ontology/field,http://dbpedia.org/ontology/training
# Entity: http://dbpedia.org/resource/Lindsay_Bartholomew, Itemset: http://dbpedia.org/ontology/country
# Entity: http://dbpedia.org/resource/Lisa_Pegher, Itemset: http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/instrument,http://dbpedia.org/ontology/occupation,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Lisa_Mishra, Itemset: http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Lloyd_Goodson, Itemset: http://dbpedia.org/ontology/deathDate,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/recordLabel
# Entity: http://dbpedia.org/resource/Lokomotif, Itemset: http://dbpedia.org/ontology/activeYearsEndYear,http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/hometown
# Entity: http://dbpedia.org/resource/Mina_Forsyth, Itemset: http://dbpedia.org/ontology/award,http://dbpedia.org/ontology/birthName,http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Minnita_Daniel-Cox, Itemset: http://dbpedia.org/ontology/nationality
# Entity: http://dbpedia.org/resource/Sam_Littlemore, Itemset: http://dbpedia.org/ontology/activeYearsStartYear,http://dbpedia.org/ontology/alias,http://dbpedia.org/ontology/background,http://dbpedia.org/ontology/genre,http://dbpedia.org/ontology/occupation,http://dbpedia.org/ontology/recordLabel

# %% [markdown]
# # Association rule mining

# %%
#Importation du fichier Texte contenant Les transactions
transactional_data = pd.read_csv(f"TRANSACTION_{date_formattee}.csv", delimiter=",")

# %%
transactional_data
# Out:
#                                               entity  \
# 0         http://dbpedia.org/resource/Cadet_(rapper)
# 1           http://dbpedia.org/resource/Caitlin_Rose
# 2          http://dbpedia.org/resource/Caleb_Schaber
# 3     http://dbpedia.org/resource/Calle_Kristiansson
# 4            http://dbpedia.org/resource/Call_Me_Ace
# ...                                              ...
# 9995       http://dbpedia.org/resource/Lloyd_Goodson
# 9996           http://dbpedia.org/resource/Lokomotif
# 9997        http://dbpedia.org/resource/Mina_Forsyth
# 9998  http://dbpedia.org/resource/Minnita_Daniel-Cox
# 9999      http://dbpedia.org/resource/Sam_Littlemore
#
#                                                 itemset
# 0     http://dbpedia.org/ontology/activeYearsEndYear...
# 1     http://dbpedia.org/ontology/activeYearsStartYe...
# 2     http://dbpedia.org/ontology/birthName,http://d...
# 3     http://dbpedia.org/ontology/activeYearsEndYear...
# 4     http://dbpedia.org/ontology/activeYearsStartYe...
# ...                                                 ...
# 9995  http://dbpedia.org/ontology/deathDate,http://d...
# 9996  http://dbpedia.org/ontology/activeYearsEndYear...
# 9997  http://dbpedia.org/ontology/award,http://dbped...
# 9998            http://dbpedia.org/ontology/nationality
# 9999  http://dbpedia.org/ontology/activeYearsStartYe...
#
# [10000 rows x 2 columns]

# %%
#Récupération des itemsets
transactional_itemset = transactional_data.iloc[:,-1].values

transactions = []
for result in transactional_itemset:
    itemset = result.split(',')
    transactions.append(itemset)


# Parcourir chaque transaction et enlever la partie http://dbpedia.org/ontology/
for transaction in transactions:
    for i in range(len(transaction)):
        transaction[i] = transaction[i].replace('http://dbpedia.org/ontology/', '')

# %%
# Afficher les transactions après suppression de la partie spécifiée
transactions
# Out:
# [['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'imdbId'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['birthName', 'deathDate', 'deathPlace', 'training'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'hometown',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'alias', 'genre', 'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'hometown',
#   'recordLabel'],
#  ['alias', 'associatedBand', 'associatedMusicalArtist', 'genre', 'hometown'],
#  ['birthName'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist'],
#  ['activeYearsStartYear', 'alias', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'occupation'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'instrument'],
#  ['activeYearsStartYear', 'birthName', 'nationality', 'occupation'],
#  ['alias', 'genre', 'occupation', 'recordLabel'],
#  ['alias', 'genre', 'hometown'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre'],
#  ['birthName', 'nationality', 'training'],
#  ['training'],
#  ['instrument'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'hometown'],
#  ['genre', 'hometown', 'instrument', 'recordLabel'],
#  ['birthName',
#   'deathDate',
#   'deathPlace',
#   'field',
#   'movement',
#   'notableWork',
#   'training'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['birthName', 'deathDate', 'deathPlace', 'field', 'notableWork'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'deathYear',
#   'nationality',
#   'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['birthName', 'deathDate', 'deathPlace', 'training'],
#  ['birthName', 'deathDate', 'deathPlace', 'field', 'movement', 'nationality'],
#  ['activeYearsStartYear', 'genre'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre', 'recordLabel'],
#  ['genre', 'recordLabel'],
#  ['deathDate'],
#  ['deathDate', 'movement', 'notableWork', 'training'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['deathDate', 'deathPlace', 'movement', 'nationality'],
#  ['deathDate'],
#  ['activeYearsStartYear', 'alias', 'genre'],
#  ['alias', 'genre', 'hometown'],
#  ['nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['nationality'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'imdbId',
#   'instrument'],
#  ['genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['foundingDate', 'location', 'numberOfVisitors', 'type'],
#  ['deathDate', 'deathPlace', 'field'],
#  ['activeYearsStartYear', 'alias'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'recordLabel'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'country', 'occupation'],
#  ['birthName',
#   'country',
#   'imdbId',
#   'occupation',
#   'parent',
#   'relative',
#   'spouse'],
#  ['imdbId', 'nationality'],
#  ['award', 'birthName', 'deathDate', 'deathPlace'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'instrument'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'genre',
#   'hometown',
#   'instrument',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'hometown',
#   'imdbId',
#   'instrument'],
#  ['deathDate', 'deathPlace'],
#  ['Person/height', 'birthName', 'deathDate', 'deathPlace', 'height', 'imdbId'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['deathDate', 'deathPlace', 'nationality', 'notableWork'],
#  ['deathDate', 'deathPlace', 'movement'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['deathDate', 'deathPlace', 'notableWork'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['deathDate', 'deathPlace', 'movement'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'deathYear',
#   'nationality',
#   'occupation'],
#  ['nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'instrument',
#   'recordLabel'],
#  ['award', 'movement', 'nationality', 'training'],
#  ['associatedBand', 'associatedMusicalArtist', 'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'hometown'],
#  ['deathDate', 'deathPlace', 'genre'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre', 'hometown'],
#  ['activeYearsStartYear', 'hometown'],
#  ['field', 'nationality', 'training'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'nationality',
#   'occupation'],
#  ['country', 'nationality'],
#  ['country'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre', 'hometown'],
#  ['activeYearsStartYear', 'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'occupation'],
#  ['field', 'nationality'],
#  ['nationality'],
#  ['activeYearsStartYear'],
#  ['activeYearsStartYear', 'alias', 'genre', 'hometown', 'occupation'],
#  ['activeYearsStartYear', 'background'],
#  ['notableWork', 'training'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown',
#   'occupation'],
#  ['activeYearsStartYear', 'genre'],
#  ['birthName', 'genre', 'imdbId', 'pseudonym'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['Person/height', 'height'],
#  ['activeYearsStartYear', 'genre'],
#  ['activeYearsStartYear',
#   'background',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['deathDate', 'field', 'nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'occupation'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear', 'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'instrument', 'occupation'],
#  ['alias', 'genre', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['activeYearsStartYear', 'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'background',
#   'deathDate',
#   'hometown'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'background', 'genre'],
#  ['activeYearsStartYear'],
#  ['activeYearsStartYear', 'background', 'genre', 'occupation'],
#  ['background', 'deathDate', 'deathPlace'],
#  ['deathDate', 'deathPlace'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'recordLabel'],
#  ['field', 'movement', 'nationality', 'training'],
#  ['award',
#   'birthName',
#   'deathDate',
#   'deathPlace',
#   'field',
#   'movement',
#   'notableWork',
#   'spouse',
#   'training'],
#  ['deathDate', 'deathPlace', 'field', 'movement'],
#  ['deathDate', 'deathPlace'],
#  ['nationality'],
#  ['background', 'deathDate', 'deathPlace', 'occupation'],
#  ['award'],
#  ['deathDate', 'deathPlace', 'field', 'nationality'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'occupation'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['soundRecording'],
#  ['activeYearsStartYear', 'genre'],
#  ['activeYearsStartYear', 'background', 'genre', 'recordLabel'],
#  ['occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'hometown',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'instrument'],
#  ['deathDate', 'genre', 'instrument', 'occupation'],
#  ['activeYearsStartYear', 'instrument'],
#  ['background', 'deathDate'],
#  ['activeYearsStartYear',
#   'alias',
#   'background',
#   'genre',
#   'hometown',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'background', 'genre', 'hometown'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'recordLabel',
#   'soundRecording'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background'],
#  ['birthName', 'genre', 'nationality'],
#  ['deathDate', 'deathPlace', 'movement'],
#  ['field', 'movement', 'nationality'],
#  ['field', 'training'],
#  ['nationality', 'training'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'genre',
#   'hometown',
#   'instrument'],
#  ['activeYearsStartYear', 'country', 'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'background',
#   'deathDate',
#   'genre',
#   'hometown',
#   'occupation'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'alias', 'genre'],
#  ['award'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['deathDate', 'deathPlace'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'instrument',
#   'occupation'],
#  ['birthName', 'field', 'nationality'],
#  ['country', 'nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'imdbId',
#   'occupation',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'instrument'],
#  ['birthName', 'deathDate', 'deathPlace', 'training'],
#  ['genre', 'instrument'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['deathDate', 'deathPlace'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear', 'instrument', 'recordLabel'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['genre', 'instrument'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'deathDate'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'background', 'recordLabel'],
#  ['award', 'field', 'movement', 'nationality'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'instrument',
#   'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'occupation',
#   'recordLabel'],
#  ['award', 'field', 'nationality', 'notableWork', 'training'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'hometown',
#   'recordLabel'],
#  ['academicDiscipline', 'almaMater', 'award', 'institution', 'knownFor'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'genre',
#   'imdbId'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'background', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'background', 'genre', 'imdbId', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'background', 'genre', 'instrument', 'recordLabel'],
#  ['deathDate', 'deathPlace'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['country', 'imdbId', 'occupation'],
#  ['country'],
#  ['deathDate', 'spouse'],
#  ['deathPlace', 'movement', 'nationality', 'training'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'country',
#   'deathDate',
#   'deathYear'],
#  ['birthName', 'deathDate', 'field', 'movement'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre'],
#  ['imdbId'],
#  ['background', 'deathDate', 'deathPlace'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre'],
#  ['associatedBand', 'associatedMusicalArtist', 'background', 'instrument'],
#  ['birthName', 'imdbId'],
#  ['activeYearsStartYear', 'background', 'genre', 'hometown'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['hometown'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['birthName',
#   'country',
#   'deathDate',
#   'deathPlace',
#   'deathYear',
#   'imdbId',
#   'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['movement'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear', 'alias', 'background', 'genre', 'recordLabel'],
#  ['alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'instrument',
#   'occupation'],
#  ['nationality', 'spouse'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'hometown'],
#  ['notableWork'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'instrument'],
#  ['Person/height', 'birthName', 'height'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre', 'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace'],
#  ['deathDate', 'deathPlace'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'recordLabel'],
#  ['award'],
#  ['deathDate', 'field', 'spouse', 'training'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'deathDate',
#   'genre',
#   'occupation'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'hometown',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['birthName', 'deathDate', 'deathPlace', 'field', 'restingPlace'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['activeYearsStartYear',
#   'background',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown',
#   'instrument',
#   'recordLabel'],
#  ['genre', 'nationality'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'occupation'],
#  ['activeYearsStartYear', 'alias', 'genre', 'hometown', 'recordLabel'],
#  ['activeYearsStartYear', 'alias', 'genre', 'imdbId', 'recordLabel'],
#  ['activeYearsStartYear', 'background', 'genre', 'instrument', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['birthName', 'occupation'],
#  ['award', 'deathDate', 'deathPlace', 'training'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['activeYearsStartYear'],
#  ['almaMater', 'field', 'influenced', 'influencedBy', 'institution'],
#  ['activeYearsStartYear', 'alias', 'genre', 'hometown'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'imdbId',
#   'recordLabel',
#   'soundRecording'],
#  ['award', 'deathPlace', 'nationality', 'training'],
#  ['field'],
#  ['birthName', 'deathDate', 'deathPlace'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['award'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['birthName', 'movement'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'hometown',
#   'instrument'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'occupation'],
#  ['background', 'genre', 'instrument'],
#  ['nationality'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'hometown'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'recordLabel'],
#  ['genre', 'spouse'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['background', 'genre'],
#  ['deathDate', 'deathPlace', 'movement', 'nationality'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['occupation'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'background', 'genre'],
#  ['activeYearsStartYear', 'genre'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['birthName', 'deathDate', 'nationality'],
#  ['birthName', 'deathDate', 'deathPlace', 'field', 'spouse', 'training'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['field'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'recordLabel'],
#  ['birthName', 'deathDate', 'deathPlace', 'field'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'alias', 'genre', 'hometown'],
#  ['activeYearsStartYear', 'background', 'instrument', 'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'instrument',
#   'occupation'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'occupation'],
#  ['spouse'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre', 'soundRecording'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'background',
#   'genre',
#   'hometown',
#   'imdbId',
#   'recordLabel'],
#  ['alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'occupation',
#   'recordLabel'],
#  ['birthName', 'imdbId'],
#  ['activeYearsStartYear', 'genre', 'hometown'],
#  ['activeYearsStartYear', 'recordLabel'],
#  ['Person/height', 'activeYearsStartYear', 'country', 'height', 'occupation'],
#  ['Person/height', 'activeYearsStartYear', 'height', 'occupation', 'relative'],
#  ['background', 'genre'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'imdbId',
#   'recordLabel'],
#  ['activeYearsStartYear', 'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre', 'instrument'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['deathDate', 'deathPlace', 'movement', 'pseudonym'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'genre',
#   'hometown'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['birthName'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'imdbId',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'associatedBand', 'associatedMusicalArtist'],
#  ['nationality', 'training'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre', 'hometown'],
#  ['genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'imdbId',
#   'recordLabel'],
#  ['genre', 'instrument'],
#  ['nationality'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['birthName', 'deathDate', 'deathPlace', 'training'],
#  ['background', 'deathDate', 'deathPlace', 'genre', 'hometown'],
#  ['country'],
#  ['deathDate', 'deathPlace', 'movement'],
#  ['award',
#   'birthName',
#   'deathDate',
#   'deathPlace',
#   'movement',
#   'nationality',
#   'training'],
#  ['activeYearsStartYear', 'country', 'occupation'],
#  ['country'],
#  ['instrument'],
#  ['nationality'],
#  ['nationality'],
#  ['deathDate', 'movement'],
#  ['birthName', 'deathDate', 'deathPlace', 'movement'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre', 'hometown'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre'],
#  ['instrument'],
#  ['deathDate', 'deathPlace', 'field', 'movement', 'nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['country'],
#  ['background'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['background', 'genre', 'recordLabel'],
#  ['background', 'genre'],
#  ['imdbId'],
#  ['activeYearsStartYear', 'genre', 'hometown'],
#  ['activeYearsStartYear', 'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist'],
#  ['activeYearsStartYear', 'background', 'genre', 'occupation'],
#  ['activeYearsStartYear', 'genre'],
#  ['country'],
#  ['activeYearsStartYear',
#   'alias',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'background', 'genre'],
#  ['associatedBand', 'associatedMusicalArtist'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'recordLabel'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre'],
#  ['training'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'hometown', 'instrument'],
#  ['genre', 'instrument'],
#  ['activeYearsStartYear', 'imdbId'],
#  ['country'],
#  ['background', 'genre'],
#  ['country'],
#  ['field', 'nationality'],
#  ['birthName',
#   'deathDate',
#   'deathPlace',
#   'field',
#   'nationality',
#   'notableWork',
#   'restingPlace'],
#  ['nationality'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['almaMater',
#   'depictionDescription',
#   'field',
#   'influenced',
#   'institution',
#   'nationality'],
#  ['field', 'training'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'deathDate',
#   'deathPlace',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'occupation'],
#  ['hometown'],
#  ['activeYearsStartYear', 'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'associatedBand', 'associatedMusicalArtist'],
#  ['background', 'deathDate'],
#  ['activeYearsStartYear', 'genre'],
#  ['field', 'training'],
#  ['nationality'],
#  ['nationality'],
#  ['nationality', 'spouse'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['birthName', 'deathDate', 'deathPlace', 'field'],
#  ['deathPlace', 'movement', 'nationality', 'notableWork', 'restingPlace'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['country'],
#  ['deathDate', 'deathPlace', 'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'instrument', 'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'recordLabel'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['genre', 'instrument'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['award',
#   'birthName',
#   'child',
#   'deathDate',
#   'deathPlace',
#   'field',
#   'spouse',
#   'training'],
#  ['birthName', 'deathDate', 'field', 'movement', 'spouse', 'training'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'instrument'],
#  ['birthName', 'movement'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre', 'recordLabel'],
#  ['deathDate', 'deathPlace', 'genre', 'occupation'],
#  ['deathDate', 'deathPlace', 'notableWork', 'restingPlace'],
#  ['activeYearsStartYear', 'alias', 'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel',
#   'soundRecording'],
#  ['deathDate', 'deathPlace'],
#  ['birthName', 'deathDate', 'deathPlace'],
#  ['nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['birthName', 'genre', 'pseudonym'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'hometown'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'recordLabel'],
#  ['birthName', 'deathDate', 'deathPlace', 'field', 'training'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'genre',
#   'hometown'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'occupation'],
#  ['birthName', 'deathDate', 'deathPlace', 'field'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['award', 'movement'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'associatedBand', 'associatedMusicalArtist'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'imdbId',
#   'instrument',
#   'recordLabel'],
#  ['award', 'deathDate', 'deathPlace', 'nationality'],
#  ['deathDate', 'deathPlace', 'deathYear'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'alias'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'deathYear',
#   'nationality',
#   'occupation'],
#  ['deathDate', 'deathPlace', 'movement', 'nationality', 'training'],
#  ['activeYearsStartYear', 'associatedBand', 'associatedMusicalArtist'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['birthName', 'deathDate', 'movement'],
#  ['deathPlace', 'field'],
#  ['genre'],
#  ['birthName', 'deathDate', 'deathPlace', 'field'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'imdbId'],
#  ['activeYearsStartYear', 'genre'],
#  ['genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'occupation'],
#  ['birthName', 'deathPlace', 'movement'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'alias'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear', 'genre'],
#  ['alias', 'deathPlace', 'genre', 'occupation'],
#  ['Person/height', 'height'],
#  ['activeYearsEndYear', 'activeYearsStartYear'],
#  ['activeYearsStartYear', 'genre', 'instrument', 'occupation', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear', 'genre', 'instrument', 'occupation', 'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'hometown', 'occupation'],
#  ['genre', 'hometown', 'instrument'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['award', 'birthName', 'deathDate', 'deathPlace'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre', 'instrument'],
#  ['birthName', 'imdbId'],
#  ['genre'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre', 'recordLabel'],
#  ['country'],
#  ['birthName', 'deathDate', 'deathPlace', 'deathYear', 'occupation'],
#  ['genre'],
#  ['genre', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'hometown'],
#  ['alias', 'associatedBand', 'associatedMusicalArtist', 'genre', 'instrument'],
#  ['country', 'occupation'],
#  ['birthName', 'deathDate'],
#  ['award'],
#  ['genre', 'instrument'],
#  ['deathDate', 'deathPlace', 'genre'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'deathDate', 'instrument'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'imdbId',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'hometown'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'imdbId',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'genre',
#   'instrument'],
#  ['deathDate', 'deathPlace', 'genre', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'occupation',
#   'recordLabel'],
#  ['hometown'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist'],
#  ['deathDate', 'deathPlace', 'field'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'birthName',
#   'deathDate',
#   'deathPlace',
#   'deathYear',
#   'nationality',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'deathYear',
#   'imdbId',
#   'nationality'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'alias', 'genre', 'hometown', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'instrument',
#   'recordLabel'],
#  ['training'],
#  ['birthName', 'deathDate', 'deathPlace', 'movement'],
#  ['activeYearsStartYear', 'hometown'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['birthName', 'deathPlace', 'movement', 'nationality', 'notableWork'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'imdbId',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'hometown'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['birthName', 'movement'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['instrument'],
#  ['activeYearsStartYear', 'genre', 'hometown'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'birthName',
#   'deathDate',
#   'deathPlace'],
#  ['deathDate', 'instrument'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'occupation'],
#  ['pseudonym'],
#  ['associatedBand', 'associatedMusicalArtist', 'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'recordLabel'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['award', 'nationality'],
#  ['nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathPlace',
#   'imdbId',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'imdbId',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'instrument',
#   'occupation'],
#  ['activeYearsStartYear', 'genre', 'imdbId', 'recordLabel', 'soundRecording'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'occupation'],
#  ['movement'],
#  ['genre', 'instrument', 'recordLabel'],
#  ['Person/height', 'birthName', 'height'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'recordLabel'],
#  ['birthName', 'country', 'occupation'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['deathDate', 'deathPlace', 'genre'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre', 'recordLabel'],
#  ['deathDate', 'deathPlace', 'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'occupation'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['genre', 'instrument', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'occupation', 'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear', 'alias'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['birthName', 'nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'genre',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'imdbId',
#   'recordLabel'],
#  ['genre'],
#  ['deathDate', 'deathPlace', 'training'],
#  ['activeYearsStartYear', 'genre', 'instrument'],
#  ['deathPlace', 'field', 'movement', 'nationality', 'training'],
#  ['genre', 'occupation'],
#  ['nationality'],
#  ['activeYearsStartYear', 'hometown'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument'],
#  ['occupation'],
#  ['genre', 'hometown'],
#  ['birthName', 'deathDate', 'deathPlace', 'nationality'],
#  ['deathDate'],
#  ['deathDate', 'deathPlace', 'field', 'training'],
#  ['Person/height', 'birthName', 'height'],
#  ['activeYearsStartYear', 'alias', 'genre', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'instrument', 'recordLabel'],
#  ['Person/height', 'birthName', 'height', 'imdbId'],
#  ['activeYearsStartYear', 'alias', 'genre', 'hometown'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['activeYearsStartYear',
#   'alias',
# ...
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'imdbId',
#   'occupation'],
#  ['alias', 'genre', 'hometown', 'instrument'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['birthName', 'genre'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'instrument',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['activeYearsStartYear',
#   'alias',
#   'genre',
#   'hometown',
#   'imdbId',
#   'recordLabel'],
#  ['nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'deathDate',
#   'genre',
#   'imdbId'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['almaMater', 'field', 'institution', 'nationality'],
#  ['field', 'nationality'],
#  ['deathDate', 'training'],
#  ['deathDate', 'deathPlace', 'spouse'],
#  ['activeYearsEndYear', 'activeYearsStartYear'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['alias', 'deathDate', 'deathPlace', 'genre', 'occupation'],
#  ['alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'instrument'],
#  ['activeYearsStartYear', 'genre', 'imdbId', 'instrument', 'recordLabel'],
#  ['deathPlace'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre', 'instrument'],
#  ['alias', 'associatedBand', 'associatedMusicalArtist', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear', 'alias', 'genre'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'imdbId'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'hometown'],
#  ['alias', 'hometown', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'deathDate', 'deathPlace'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'imdbId',
#   'instrument'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['country'],
#  ['country'],
#  ['deathDate', 'field', 'movement', 'nationality'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'instrument',
#   'recordLabel'],
#  ['birthName'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre'],
#  ['field', 'training'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'occupation'],
#  ['activeYearsStartYear', 'hometown'],
#  ['activeYearsStartYear', 'instrument'],
#  ['nationality'],
#  ['hometown', 'occupation'],
#  ['birthName', 'movement'],
#  ['genre', 'instrument'],
#  ['genre'],
#  ['nationality', 'training'],
#  ['country', 'nationality'],
#  ['activeYearsStartYear'],
#  ['award', 'training'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre'],
#  ['country'],
#  ['country'],
#  ['instrument'],
#  ['field'],
#  ['field', 'nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathPlace',
#   'deathYear',
#   'occupation'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre', 'hometown'],
#  ['activeYearsStartYear', 'occupation'],
#  ['birthName', 'spouse', 'training'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'alias', 'hometown'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['country', 'imdbId'],
#  ['country'],
#  ['nationality'],
#  ['nationality'],
#  ['deathPlace', 'training'],
#  ['country', 'occupation'],
#  ['birthName', 'training'],
#  ['country'],
#  ['deathPlace', 'movement', 'notableWork'],
#  ['nationality'],
#  ['deathDate', 'deathPlace'],
#  ['genre', 'occupation'],
#  ['nationality'],
#  ['nationality'],
#  ['occupation'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'genre', 'hometown'],
#  ['country'],
#  ['birthName', 'deathDate', 'deathPlace'],
#  ['Person/height', 'birthName', 'height'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['country', 'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'genre'],
#  ['activeYearsStartYear', 'background', 'genre', 'imdbId', 'recordLabel'],
#  ['alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsStartYear', 'alias', 'genre', 'hometown'],
#  ['activeYearsStartYear', 'genre', 'occupation', 'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear', 'genre', 'hometown'],
#  ['activeYearsStartYear', 'knownFor', 'occupation'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['deathDate', 'movement'],
#  ['deathDate'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear', 'hometown'],
#  ['birthName', 'nationality'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'instrument',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear', 'genre', 'hometown'],
#  ['activeYearsStartYear', 'genre', 'hometown', 'occupation'],
#  ['alias', 'hometown', 'instrument', 'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['award'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'occupation'],
#  ['birthName', 'deathDate', 'deathPlace', 'movement', 'training'],
#  ['birthName', 'deathDate', 'deathPlace', 'nationality'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'country',
#   'deathDate',
#   'deathPlace',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear', 'background', 'instrument'],
#  ['birthName', 'training'],
#  ['birthName',
#   'deathDate',
#   'deathPlace',
#   'field',
#   'nationality',
#   'restingPlace'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'deathYear',
#   'imdbId',
#   'occupation',
#   'spouse'],
#  ['background', 'deathDate', 'deathPlace'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['associatedBand', 'associatedMusicalArtist', 'hometown'],
#  ['deathDate', 'deathPlace', 'hometown'],
#  ['activeYearsStartYear'],
#  ['award'],
#  ['recordLabel'],
#  ['birthName', 'deathDate', 'deathPlace', 'field', 'nationality'],
#  ['activeYearsStartYear', 'background', 'genre', 'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['award', 'deathDate', 'deathPlace', 'field', 'spouse'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsStartYear', 'background', 'genre', 'recordLabel'],
#  ['deathDate', 'deathPlace', 'training'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'deathPlace'],
#  ['deathDate', 'nationality', 'training'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'birthName',
#   'deathDate',
#   'deathPlace'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['academicDiscipline', 'almaMater', 'award', 'birthName', 'institution'],
#  ['deathDate'],
#  ['birthName', 'deathDate', 'deathPlace', 'field', 'nationality'],
#  ['deathDate', 'spouse'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel',
#   'soundRecording'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'background', 'genre'],
#  ['activeYearsStartYear', 'genre'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'occupation',
#   'recordLabel'],
#  ['country', 'deathDate', 'deathYear', 'occupation'],
#  ['country'],
#  ['award', 'deathDate', 'deathPlace', 'notableWork', 'training'],
#  ['deathDate', 'deathPlace', 'training'],
#  ['deathDate', 'deathPlace', 'movement', 'restingPlace'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['deathDate', 'deathPlace', 'notableWork', 'training'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'recordLabel'],
#  ['birthName', 'imdbId'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'occupation',
#   'recordLabel'],
#  ['alias', 'background', 'deathDate', 'deathPlace', 'genre'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'genre',
#   'hometown'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ['alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'occupation',
#   'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'deathDate',
#   'deathPlace',
#   'genre',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['genre', 'hometown', 'instrument', 'recordLabel'],
#  ['nationality'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'genre',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear', 'alias', 'background', 'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'genre',
#   'instrument',
#   'occupation',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'instrument',
#   'occupation'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'deathDate',
#   'deathPlace',
#   'genre'],
#  ['activeYearsStartYear', 'genre'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'hometown',
#   'imdbId',
#   'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'background'],
#  ['activeYearsStartYear', 'occupation'],
#  ['birthName'],
#  ['activeYearsStartYear', 'genre', 'recordLabel'],
#  ['activeYearsStartYear', 'background', 'genre', 'hometown', 'recordLabel'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'instrument'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown',
#   'occupation'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'instrument',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'instrument'],
#  ['associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'instrument'],
#  ['birthName'],
#  ['activeYearsStartYear', 'genre', 'imdbId'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsEndYear', 'activeYearsStartYear', 'recordLabel'],
#  ['associatedBand', 'associatedMusicalArtist', 'genre'],
#  ['activeYearsStartYear', 'alias', 'recordLabel'],
#  ['activeYearsEndYear',
#   'activeYearsStartYear',
#   'background',
#   'deathDate',
#   'genre'],
#  ['activeYearsStartYear',
#   'alias',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown',
#   'recordLabel'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'genre',
#   'hometown',
#   'instrument',
#   'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'background',
#   'hometown',
#   'instrument',
#   'occupation'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre',
#   'hometown'],
#  ['birthName'],
#  ['country'],
#  ['activeYearsStartYear',
#   'birthName',
#   'country',
#   'imdbId',
#   'nationality',
#   'occupation',
#   'stateOfOrigin'],
#  ['alias', 'country', 'nationality', 'occupation', 'stateOfOrigin'],
#  ['activeYearsStartYear',
#   'associatedBand',
#   'associatedMusicalArtist',
#   'genre'],
#  ...]

# %%
# Convertissez chaque transaction en un ensemble
transactions = [set(transaction) for transaction in transactions]

# Créez un dictionnaire pour mapper les prédicats aux entiers
predicate_to_int = {predicate: i for i, predicate in enumerate(set.union(*transactions))}

# Traduction inverse de int_to_predicate
int_to_predicate = {value: key for key, value in predicate_to_int.items()}

# Mappez les prédicats aux entiers dans les transactions
transaction_data_for_Apriori = [[predicate_to_int[predicate] for predicate in transaction] for transaction in transactions]

# %%
transaction_data_for_Apriori
# Out:
# [[53, 0, 24, 7, 19, 10, 11, 26],
#  [0, 7, 40, 10, 11, 52],
#  [26, 24, 27, 60],
#  [0, 28, 7, 19, 40, 12, 52],
#  [0, 20, 12, 7],
#  [0, 7, 10, 11, 52],
#  [10, 7, 40, 20, 11, 52],
#  [0, 10, 20, 11, 52],
#  [60],
#  [0, 7, 40, 10, 11, 52],
#  [0, 7, 40, 10, 11, 52],
#  [19, 10, 11, 7],
#  [20, 40, 7],
#  [0, 7, 10, 11, 12],
#  [0, 52, 28, 7],
#  [35, 12, 60, 7],
#  [0, 20, 40, 12],
#  [0, 20, 52],
#  [0, 24, 7, 19, 20, 40, 26],
#  [0, 7],
#  [35, 27, 60],
#  [27],
#  [28],
#  [0, 10, 11, 7],
#  [0, 10, 11, 7],
#  [0, 7, 40, 10, 11, 52],
#  [0, 52, 7],
#  [0, 40, 52, 28],
#  [27, 30, 33, 24, 50, 60, 26],
#  [19, 0, 7],
#  [0, 7, 40, 10, 11],
#  [0, 7, 40, 10, 11],
#  [0, 7, 40, 10, 11],
#  [30, 24, 50, 60, 26],
#  [24, 6, 35, 7, 19, 12, 26],
#  [0, 28, 7, 40, 10, 11, 52],
#  [0, 24, 7, 40, 19, 10, 11, 26],
#  [0, 24, 10, 7, 40, 19, 20, 11, 26],
#  [26, 24, 27, 60],
#  [33, 24, 35, 50, 60, 26],
#  [0, 7],
#  [0, 10, 11, 40],
#  [0, 40],
#  [24],
#  [33, 30, 24, 27],
#  [0, 40, 7],
#  [33, 35, 24, 26],
#  [24],
#  [0, 15, 24, 10, 11, 26],
#  [0, 28, 7, 19, 40, 12],
#  [0, 10, 11, 7],
#  [10, 40, 20, 11, 12],
#  [0, 24, 40, 10, 11, 26],
#  [0, 10, 7, 40, 20, 11, 52],
#  [0, 40, 52, 28],
#  [35],
#  [0, 15, 24, 7, 19, 10, 11],
#  [0, 28, 7, 19, 40, 12],
#  [0, 20, 15, 7],
#  [0, 24, 7, 19, 26],
#  [0, 15, 28, 24, 7, 40, 19, 10, 11, 12],
#  [0, 28, 7, 10, 11, 12, 52],
#  [0, 15, 24, 10, 7, 19, 20, 11, 26],
#  [0, 7],
#  [53, 10, 7, 40, 20, 11, 52],
#  [10, 11, 15],
#  [12, 7],
#  [60],
#  [0, 40, 7],
#  [0, 15, 7, 40, 52],
#  [0, 15, 28, 10, 11],
#  [0, 15, 10, 7, 40, 20, 11, 52],
#  [0, 15, 7, 10, 11, 12, 52],
#  [0, 15, 28, 10, 7, 40, 20, 11],
#  [0, 28, 7, 10, 11],
#  [0, 15, 28, 10, 11],
#  [60],
#  [53, 0, 7],
#  [0, 7, 40, 19, 10, 11, 52],
#  [19, 40, 7],
#  [0, 10, 11],
#  [20, 40, 7],
#  [0, 15, 24, 7, 19],
#  [0, 10, 7, 40, 20, 11, 52],
#  [0, 15, 28, 7, 10, 11, 12, 52],
#  [15, 28, 7, 10, 11, 12, 52],
#  [0, 7, 10, 11, 52],
#  [60],
#  [13],
#  [53, 12, 35, 7, 18, 13, 60],
#  [12, 35, 18, 20, 13],
#  [0, 10, 11, 7],
#  ...]

# %%
# Écrivez les transactions Mapper dans un fichier
with open('transaction_data_for_Apriori.txt', 'w') as f:
    for transaction in transaction_data_for_Apriori:
        f.write(' '.join(map(str, transaction)) + '\n')

# %%
# Installation de Java
# !apt-get install -y openjdk-8-jdk-headless -qq > /dev/null

# Téléchargement de SPMF
# !wget http://www.philippe-fournier-viger.com/spmf/spmf.jar
# Out:
# --2023-12-05 21:28:04--  http://www.philippe-fournier-viger.com/spmf/spmf.jar
# Resolving www.philippe-fournier-viger.com (www.philippe-fournier-viger.com)... 104.21.33.228, 172.67.193.154, 2606:4700:3035::ac43:c19a, ...
# Connecting to www.philippe-fournier-viger.com (www.philippe-fournier-viger.com)|104.21.33.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12692580 (12M) [application/java-archive]
# Saving to: ‘spmf.jar’
#
# spmf.jar            100%[===================>]  12.10M  40.7MB/s    in 0.3s
#
# 2023-12-05 21:28:04 (40.7 MB/s) - ‘spmf.jar’ saved [12692580/12692580]

# %%
# Exécution de SPMF
# !java -jar spmf.jar run Apriori_association_rules transaction_data_for_Apriori.txt output.txt 0.01 0.7
# Out:
# >/content/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 368
#  The algorithm stopped at size 5
#  Frequent itemsets count : 114
#  Maximum memory usage : 4.5508575439453125 mb
#  Total time ~ 211 ms
# ===================================================
# =============  ASSOCIATION RULE GENERATION v2.19- STATS =============
#  Number of association rules generated : 45
#  Total time ~ 4 ms
# ===================================================

# %%
# Lecture des résultats
with open('output.txt', 'r') as f:
    rules = f.read().split('\n')

# %%
rules
# Out:
# ['15 ==> 0 #SUP: 1436 #CONF: 0.7409700722394221',
#  '28 ==> 0 #SUP: 1199 #CONF: 0.7545626179987414',
#  '40 ==> 0 #SUP: 2351 #CONF: 0.8496566678713408',
#  '52 ==> 0 #SUP: 1653 #CONF: 0.8035974720466699',
#  '7 10 ==> 0 #SUP: 131 #CONF: 0.9924242424242424',
#  '7 11 ==> 0 #SUP: 131 #CONF: 0.9924242424242424',
#  '7 19 ==> 0 #SUP: 113 #CONF: 0.9495798319327731',
#  '7 40 ==> 0 #SUP: 533 #CONF: 0.9586330935251799',
#  '7 52 ==> 0 #SUP: 389 #CONF: 0.9534313725490197',
#  '0 11 ==> 10 #SUP: 438 #CONF: 1.0',
#  '10 20 ==> 0 #SUP: 100 #CONF: 0.9259259259259259',
#  '10 40 ==> 0 #SUP: 146 #CONF: 0.7604166666666666',
#  '10 52 ==> 0 #SUP: 217 #CONF: 0.8509803921568627',
#  '11 52 ==> 0 #SUP: 116 #CONF: 0.8',
#  '15 24 ==> 0 #SUP: 216 #CONF: 0.7422680412371134',
#  '15 28 ==> 0 #SUP: 434 #CONF: 0.8714859437751004',
#  '15 40 ==> 0 #SUP: 704 #CONF: 0.9166666666666666',
#  '15 52 ==> 0 #SUP: 456 #CONF: 0.8702290076335878',
#  '20 40 ==> 0 #SUP: 125 #CONF: 0.8333333333333334',
#  '20 52 ==> 0 #SUP: 178 #CONF: 0.8476190476190476',
#  '0 26 ==> 24 #SUP: 201 #CONF: 0.9436619718309859',
#  '24 40 ==> 0 #SUP: 258 #CONF: 0.911660777385159',
#  '28 40 ==> 0 #SUP: 509 #CONF: 0.9478584729981379',
#  '28 52 ==> 0 #SUP: 341 #CONF: 0.9266304347826086',
#  '40 52 ==> 0 #SUP: 846 #CONF: 0.9225736095965104',
#  '7 11 ==> 10 #SUP: 132 #CONF: 1.0',
#  '7 10 ==> 11 #SUP: 132 #CONF: 1.0',
#  '11 12 ==> 10 #SUP: 101 #CONF: 1.0',
#  '10 12 ==> 11 #SUP: 101 #CONF: 1.0',
#  '11 52 ==> 10 #SUP: 145 #CONF: 1.0',
#  '15 26 ==> 24 #SUP: 104 #CONF: 0.9541284403669725',
#  '7 10 11 ==> 0 #SUP: 131 #CONF: 0.9924242424242424',
#  '0 7 11 ==> 10 #SUP: 131 #CONF: 1.0',
#  '0 7 10 ==> 11 #SUP: 131 #CONF: 1.0',
#  '7 11 ==> 0 10 #SUP: 131 #CONF: 0.9924242424242424',
#  '7 10 ==> 0 11 #SUP: 131 #CONF: 0.9924242424242424',
#  '7 40 52 ==> 0 #SUP: 264 #CONF: 0.946236559139785',
#  '10 11 52 ==> 0 #SUP: 116 #CONF: 0.8',
#  '0 11 52 ==> 10 #SUP: 116 #CONF: 1.0',
#  '11 52 ==> 0 10 #SUP: 116 #CONF: 0.8',
#  '15 24 40 ==> 0 #SUP: 102 #CONF: 0.9026548672566371',
#  '15 28 40 ==> 0 #SUP: 193 #CONF: 0.946078431372549',
#  '15 28 52 ==> 0 #SUP: 124 #CONF: 0.9185185185185185',
#  '15 40 52 ==> 0 #SUP: 218 #CONF: 0.9356223175965666',
#  '28 40 52 ==> 0 #SUP: 173 #CONF: 0.9453551912568307',
#  '']

# %%
#Dans le code suivant nous récupérions les rules générés en récupérant le support et le confidence
rule_generate = []
sup_conf_generated = []
for rule in rules:
  if rule!="":
    rule_generate.append(rule.split(" #SUP: ")[0])
    sup_conf_generated.append(rule.split(" #SUP: ")[1].split(" #CONF: "))

# %%
# Parcourir les règles et effectuer la traduction inverse
tab_rules_generate = []
for rule in rule_generate:
    if rule!="":
        items = rule.split(" ==> ")  # Trouver tous les entiers dans la règle
        antecedent = items[0]  # Le premier élément est l'antécédent
        consequent = items[1]  # Le deuxième élément est le conséquent

        # Traduire les entiers aux prédicats dans l'antécédent et le conséquent
        antecedent_predicates = [int_to_predicate[int(item)] for item in antecedent.split(" ")]
        consequent_predicates = [int_to_predicate[int(item)] for item in consequent.split(" ")]

        # Afficher la règle avec les prédicats
        rules_generates_format = f"{{{', '.join(antecedent_predicates)}}} -> {{{', '.join(consequent_predicates)}}}"
        tab_rules_generate.append(rules_generates_format)
        print(f"{', '.join(antecedent_predicates)} => {', '.join(consequent_predicates)}")
# Out:
# background => genre
# instrument => genre
# recordLabel => genre
# hometown => genre
# activeYearsStartYear, associatedMusicalArtist => genre
# activeYearsStartYear, associatedBand => genre
# activeYearsStartYear, activeYearsEndYear => genre
# activeYearsStartYear, recordLabel => genre
# activeYearsStartYear, hometown => genre
# genre, associatedBand => associatedMusicalArtist
# associatedMusicalArtist, alias => genre
# associatedMusicalArtist, recordLabel => genre
# associatedMusicalArtist, hometown => genre
# associatedBand, hometown => genre
# background, deathDate => genre
# background, instrument => genre
# background, recordLabel => genre
# background, hometown => genre
# alias, recordLabel => genre
# alias, hometown => genre
# genre, deathPlace => deathDate
# deathDate, recordLabel => genre
# instrument, recordLabel => genre
# instrument, hometown => genre
# recordLabel, hometown => genre
# activeYearsStartYear, associatedBand => associatedMusicalArtist
# activeYearsStartYear, associatedMusicalArtist => associatedBand
# associatedBand, occupation => associatedMusicalArtist
# associatedMusicalArtist, occupation => associatedBand
# associatedBand, hometown => associatedMusicalArtist
# background, deathPlace => deathDate
# activeYearsStartYear, associatedMusicalArtist, associatedBand => genre
# genre, activeYearsStartYear, associatedBand => associatedMusicalArtist
# genre, activeYearsStartYear, associatedMusicalArtist => associatedBand
# activeYearsStartYear, associatedBand => genre, associatedMusicalArtist
# activeYearsStartYear, associatedMusicalArtist => genre, associatedBand
# activeYearsStartYear, recordLabel, hometown => genre
# associatedMusicalArtist, associatedBand, hometown => genre
# genre, associatedBand, hometown => associatedMusicalArtist
# associatedBand, hometown => genre, associatedMusicalArtist
# background, deathDate, recordLabel => genre
# background, instrument, recordLabel => genre
# background, instrument, hometown => genre
# background, recordLabel, hometown => genre
# instrument, recordLabel, hometown => genre

# %% [markdown]
# # Query Generation

# %%
#Dans cette fonction nous avons implémenter les trois cas de query mise dans le PROJET.
#Par défaut nombre de cas est égale à 1, ce qui veut dire qu'un seul query sera renvoyer dans un tableau
def generate_sparql_queries(input_string, int_to_predicate, nombre_de_cas = 1):
    sparql_queries = []
    prefix = "PREFIX dbo: <http://dbpedia.org/ontology/>\n"
    rules = input_string.split(" -> ")
    if len(rules) != 2:
        print("Format d'entrée invalide.")
        return sparql_queries

    if nombre_de_cas >= 1:
      antecedent_predicates = rules[0][1:-1].split(', ')
      consequent_predicates = rules[1][1:-1].split(', ')

      # Generate SPARQL query clauses for antecedent and consequent
      antecedent_clause_case1 = '.\n'.join([f"?subject dbo:{pred} ?ant{i}" for i, pred in enumerate(antecedent_predicates, start=1)])
      consequent_clause_case1 = '.\n'.join([f"?subject dbo:{pred} ?cons{i}" for i, pred in enumerate(consequent_predicates, start=1)])

      select_clause_case1 = f"SELECT DISTINCT * WHERE {{\n {antecedent_clause_case1}.\n"
      where_clause_case1 = f"{{\n SELECT DISTINCT * {{\n {consequent_clause_case1}.\n}}\n}}"

      # Create the final SPARQL query
      sparql_query_case1 = f"{prefix}{select_clause_case1}{where_clause_case1}\n}}"
      sparql_queries.append(sparql_query_case1)

    if nombre_de_cas >= 2:
      # Generate SPARQL query clauses for antecedent and consequent
      antecedent_clause_case_2 = '.\n'.join([f"?subject dbo:{pred} ?const{i}" for i, pred in enumerate(consequent_predicates, start=1)])
      consequent_clause_case_2 = '.\n'.join([f"?subject dbo:{pred} ?ant{i}" for i, pred in enumerate(antecedent_predicates, start=1)])

      select_clause_case_2 = f"SELECT DISTINCT * WHERE {{\n {antecedent_clause_case_2}.\n"
      where_clause_case_2 = f"{{\n SELECT DISTINCT * {{\n {consequent_clause_case_2}.\n}}\n}}"

      # Create the final SPARQL query
      sparql_query_case_2 = f"{prefix}{select_clause_case_2}{where_clause_case_2}\n}}"
      sparql_queries.append(sparql_query_case_2)


    if nombre_de_cas >= 3:
      # Generate SPARQL query clauses for antecedent and consequent
      antecedent_clause_case_3 = '.\n'.join([f"?subject dbo:{pred} ?const{i}" for i, pred in enumerate(consequent_predicates, start=1)])
      consequent_clause_case_3 = '.\n'.join([f"?subject dbo:{pred} ?ant{i}" for i, pred in enumerate(antecedent_predicates, start=1)])

      select_clause_case_3 = f"SELECT DISTINCT * WHERE {{\n{antecedent_clause_case_3}.\n"
      where_clause_case_3 = f"{consequent_clause_case_3}.\n}}"

      # Create the final SPARQL query
      sparql_query_case_3 = f"{prefix}{select_clause_case_3}{where_clause_case_3}\n"
      sparql_queries.append(sparql_query_case_3)

    return sparql_queries

# %%
query_generates = []
for rule in tab_rules_generate:
    # Utilisation de la fonction pour générer les requêtes SPARQL
    generated_sparql_querie = generate_sparql_queries(rule, int_to_predicate)
    query_generates.append(generated_sparql_querie[0])
    # Affichage des requêtes SPARQL générées
    print(f"Requêtes SPARQL générées à partir de l'entrée {rule} :")
    print(generated_sparql_querie[0])
    print("\n\n")
# Out:
# Requêtes SPARQL générées à partir de l'entrée {background} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:background ?ant1.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {instrument} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:instrument ?ant1.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {recordLabel} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:recordLabel ?ant1.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:hometown ?ant1.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, associatedMusicalArtist} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:associatedMusicalArtist ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, associatedBand} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:associatedBand ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, activeYearsEndYear} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:activeYearsEndYear ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, recordLabel} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:recordLabel ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:hometown ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {genre, associatedBand} -> {associatedMusicalArtist} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:genre ?ant1.
# ?subject dbo:associatedBand ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:associatedMusicalArtist ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {associatedMusicalArtist, alias} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:associatedMusicalArtist ?ant1.
# ?subject dbo:alias ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {associatedMusicalArtist, recordLabel} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:associatedMusicalArtist ?ant1.
# ?subject dbo:recordLabel ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {associatedMusicalArtist, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:associatedMusicalArtist ?ant1.
# ?subject dbo:hometown ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {associatedBand, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:associatedBand ?ant1.
# ?subject dbo:hometown ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {background, deathDate} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:background ?ant1.
# ?subject dbo:deathDate ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {background, instrument} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:background ?ant1.
# ?subject dbo:instrument ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {background, recordLabel} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:background ?ant1.
# ?subject dbo:recordLabel ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {background, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:background ?ant1.
# ?subject dbo:hometown ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {alias, recordLabel} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:alias ?ant1.
# ?subject dbo:recordLabel ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {alias, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:alias ?ant1.
# ?subject dbo:hometown ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {genre, deathPlace} -> {deathDate} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:genre ?ant1.
# ?subject dbo:deathPlace ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:deathDate ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {deathDate, recordLabel} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:deathDate ?ant1.
# ?subject dbo:recordLabel ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {instrument, recordLabel} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:instrument ?ant1.
# ?subject dbo:recordLabel ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {instrument, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:instrument ?ant1.
# ?subject dbo:hometown ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {recordLabel, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:recordLabel ?ant1.
# ?subject dbo:hometown ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, associatedBand} -> {associatedMusicalArtist} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:associatedBand ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:associatedMusicalArtist ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, associatedMusicalArtist} -> {associatedBand} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:associatedMusicalArtist ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:associatedBand ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {associatedBand, occupation} -> {associatedMusicalArtist} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:associatedBand ?ant1.
# ?subject dbo:occupation ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:associatedMusicalArtist ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {associatedMusicalArtist, occupation} -> {associatedBand} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:associatedMusicalArtist ?ant1.
# ?subject dbo:occupation ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:associatedBand ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {associatedBand, hometown} -> {associatedMusicalArtist} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:associatedBand ?ant1.
# ?subject dbo:hometown ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:associatedMusicalArtist ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {background, deathPlace} -> {deathDate} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:background ?ant1.
# ?subject dbo:deathPlace ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:deathDate ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, associatedMusicalArtist, associatedBand} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:associatedMusicalArtist ?ant2.
# ?subject dbo:associatedBand ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {genre, activeYearsStartYear, associatedBand} -> {associatedMusicalArtist} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:genre ?ant1.
# ?subject dbo:activeYearsStartYear ?ant2.
# ?subject dbo:associatedBand ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:associatedMusicalArtist ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {genre, activeYearsStartYear, associatedMusicalArtist} -> {associatedBand} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:genre ?ant1.
# ?subject dbo:activeYearsStartYear ?ant2.
# ?subject dbo:associatedMusicalArtist ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:associatedBand ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, associatedBand} -> {genre, associatedMusicalArtist} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:associatedBand ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# ?subject dbo:associatedMusicalArtist ?cons2.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, associatedMusicalArtist} -> {genre, associatedBand} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:associatedMusicalArtist ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# ?subject dbo:associatedBand ?cons2.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {activeYearsStartYear, recordLabel, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:activeYearsStartYear ?ant1.
# ?subject dbo:recordLabel ?ant2.
# ?subject dbo:hometown ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {associatedMusicalArtist, associatedBand, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:associatedMusicalArtist ?ant1.
# ?subject dbo:associatedBand ?ant2.
# ?subject dbo:hometown ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {genre, associatedBand, hometown} -> {associatedMusicalArtist} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:genre ?ant1.
# ?subject dbo:associatedBand ?ant2.
# ?subject dbo:hometown ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:associatedMusicalArtist ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {associatedBand, hometown} -> {genre, associatedMusicalArtist} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:associatedBand ?ant1.
# ?subject dbo:hometown ?ant2.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# ?subject dbo:associatedMusicalArtist ?cons2.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {background, deathDate, recordLabel} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:background ?ant1.
# ?subject dbo:deathDate ?ant2.
# ?subject dbo:recordLabel ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {background, instrument, recordLabel} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:background ?ant1.
# ?subject dbo:instrument ?ant2.
# ?subject dbo:recordLabel ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {background, instrument, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:background ?ant1.
# ?subject dbo:instrument ?ant2.
# ?subject dbo:hometown ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {background, recordLabel, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:background ?ant1.
# ?subject dbo:recordLabel ?ant2.
# ?subject dbo:hometown ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }
#
#
#
# Requêtes SPARQL générées à partir de l'entrée {instrument, recordLabel, hometown} -> {genre} :
# PREFIX dbo: <http://dbpedia.org/ontology/>
# SELECT DISTINCT * WHERE {
#  ?subject dbo:instrument ?ant1.
# ?subject dbo:recordLabel ?ant2.
# ?subject dbo:hometown ?ant3.
# {
#  SELECT DISTINCT * {
#  ?subject dbo:genre ?cons1.
# }
# }
# }

# %% [markdown]
# # Query validation

# %%
for i in range(3):
    endpoint = "http://dbpedia.org/sparql"
    results = execute_sparql_query(endpoint, query_generates[i])
    resultat_ent= results["results"]["bindings"]
    print(f"Query{i}, Number résultat : {len(resultat_ent)}\n")
# Out:
# Query0, Number résultat : 10000
#
# Query1, Number résultat : 10000
#
# Query2, Number résultat : 10000

# %% [markdown]
# # the list of top-10 most frequent

# %%
top_10_frequent_queries = query_generates[:10]
top_10_frequent_queries_sup_conf = sup_conf_generated[:10]
top_10_tab_rules_generate = tab_rules_generate[:10]

# %%
#Cette fonction nous permettra de calculer le support de Y par rapport aux règles générés par l'algo de Apriori
def calcul_support_Y(rules, Y):
  somme = 0
  for rule in rules:
    if str(Y) == rule.split(" -> ")[1]:
      somme+=1
  return somme

# %%
dic = {}

for i in range(len(top_10_frequent_queries_sup_conf)):

    support_y = calcul_support_Y(tab_rules_generate, top_10_tab_rules_generate[i].split(" -> ")[1]) /len(tab_rules_generate)
    conf_x_y = top_10_frequent_queries_sup_conf[i][1]
    lift = float(conf_x_y) / support_y

    dic[i] = {
        "X->Y"  : top_10_tab_rules_generate[i],
        "conf" : conf_x_y,
        "lift" : lift
    }

# %%
dataframe = pd.DataFrame(dic)
dataframe = dataframe.T
dataframe
# Out:
#                                                 X->Y                conf  \
# 0                            {background} -> {genre}  0.7409700722394221
# 1                            {instrument} -> {genre}  0.7545626179987414
# 2                           {recordLabel} -> {genre}  0.8496566678713408
# 3                              {hometown} -> {genre}  0.8035974720466699
# 4  {activeYearsStartYear, associatedMusicalArtist...  0.9924242424242424
# 5  {activeYearsStartYear, associatedBand} -> {genre}  0.9924242424242424
# 6  {activeYearsStartYear, activeYearsEndYear} -> ...  0.9495798319327731
# 7     {activeYearsStartYear, recordLabel} -> {genre}  0.9586330935251799
# 8        {activeYearsStartYear, hometown} -> {genre}  0.9534313725490197
# 9  {genre, associatedBand} -> {associatedMusicalA...                 1.0
#
#        lift
# 0  1.075602
# 1  1.095333
# 2  1.233373
# 3  1.166512
# 4  1.440616
# 5  1.440616
# 6  1.378422
# 7  1.391564
# 8  1.384013
# 9       7.5
